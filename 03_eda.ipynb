# %% [markdown]
# # 3. Exploratory Data Analysis (EDA)
#
# Exploratory Data Analysis is used to understand the GPS movement dataset.
#
# The analysis includes:
#
# - Number of records and users
# - Latitude and longitude distribution
# - Movement patterns
# - Time-based movement patterns
# - Distance and speed analysis
# - Identification of unusual movement patterns
#
# EDA helps us understand the data before applying machine learning algorithms.
