# %% [markdown]
# # CASEFILE: AI-Powered Missing Person Investigation and Location Prediction System
#
# ## 1. Data Collection
#
# This project uses GPS movement data for an academic simulation.
#
# The dataset contains:
# - User ID
# - Date
# - Time
# - Latitude
# - Longitude
#
# The data is used to study movement patterns and demonstrate machine learning techniques for location prediction.
#
# The project uses synthetic/public data and does not contain real missing-person personal information.
